# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11156890708","type":"PushEvent","actor":{"id":1597567,"login":"ACT1GMR","display_login":"ACT1GMR","gravatar_id":"","url":"https://api.github.com/users/ACT1GMR","avatar_url":"https://avatars.githubusercontent.com/u/1597567?"},"repo":{"id":147216804,"name":"ACT1GMR/podchatwebapp","url":"https://api.github.com/repos/ACT1GMR/podchatwebapp"},"payload":{"push_id":4434300573,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ff665dc4ab1ad6b0f5c321cfe7712f880dec0018","before":"0708ff1da86f77b56d5c6f9b33266236b74e8a6a","commits":[{"sha":"ff665dc4ab1ad6b0f5c321cfe7712f880dec0018","author":{"email":"act1gmr@gmail.com","name":"b.salarinia"},"message":"refactored","distinct":true,"url":"https://api.github.com/repos/ACT1GMR/podchatwebapp/commits/ff665dc4ab1ad6b0f5c321cfe7712f880dec0018"}]},"public":true,"created_at":"2019-12-25T09:35:00Z"},{"id":"11156890705","type":"PushEvent","actor":{"id":31173107,"login":"postgresql-cfbot","display_login":"postgresql-cfbot","gravatar_id":"","url":"https://api.github.com/users/postgresql-cfbot","avatar_url":"https://avatars.githubusercontent.com/u/31173107?"},"repo":{"id":100835434,"name":"postgresql-cfbot/postgresql","url":"https://api.github.com/repos/postgresql-cfbot/postgresql"},"payload":{"push_id":4434300571,"size":3,"distinct_size":1,"ref":"refs/heads/commitfest/26/2244","head":"f63b211be6dd7dc13c2983dd42f36e18cc4e7b9f","before":"8aab73dbafcaaf38ba6cfbd5f4b237b08d6814e4","commits":[{"sha":"c4dcd9144ba64946c9f9466748bdb2c51719c8a3","author":{"email":"alvherre@alvh.no-ip.org","name":"Alvaro Herrera"},"message":"Avoid splitting C string literals with \\\\-newline\\n\\nUsing \\\\ is unnecessary and ugly, so remove that.  While at it, stitch\\nthe literals back into a single line: we\'ve long discouraged splitting\\nerror message literals even when they go past the 80 chars line limit,\\nto improve greppability.\\n\\nLeave contrib/tablefunc alone.\\n\\nDiscussion: https://postgr.es/m/20191223195156.GA12271@alvherre.pgsql","distinct":false,"url":"https://api.github.com/repos/postgresql-cfbot/postgresql/commits/c4dcd9144ba64946c9f9466748bdb2c51719c8a3"},{"sha":"8ce3aa9b5914d1ac45ed3f9bc484f66b3c4850c7","author":{"email":"michael@paquier.xyz","name":"Michael Paquier"},"message":"Rename files and headers related to index AM\\n\\nThe following renaming is done so as source files related to index\\naccess methods are more consistent with table access methods (the\\noriginal names used for index AMs ware too generic, and could be\\nconfused as including features related to table AMs):\\n- amapi.h -> indexam.h.\\n- amapi.c -> indexamapi.c.  Here we have an equivalent with\\nbackend/access/table/tableamapi.c.\\n- amvalidate.c -> indexamvalidate.c.\\n- amvalidate.h -> indexamvalidate.h.\\n- genam.c -> indexgenam.c.\\n- genam.h -> indexgenam.h.\\n\\nThis has been discussed during the development of v12 when table AM was\\nworked on, but the renaming never happened.\\n\\nAuthor: Michael Paquier\\nReviewed-by: Fabien Coelho, Julien Rouhaud\\nDiscussion: https://postgr.es/m/20191223053434.GF34339@paquier.xyz","distinct":false,"url":"https://api.github.com/repos/postgresql-cfbot/postgresql/commits/8ce3aa9b5914d1ac45ed3f9bc484f66b3c4850c7"},{"sha":"f63b211be6dd7dc13c2983dd42f36e18cc4e7b9f","author":{"email":"cfbot@cputube.org","name":"Commitfest Bot"},"message":"[CF 26/2244] Allow cluster owner to bypass authentication\\n\\nThis commit was automatically generated by a robot at cfbot.cputube.org.\\nIt is based on patches submitted to the PostgreSQL mailing lists and\\nregistered in the PostgreSQL Commitfest application.\\n\\nThis branch will be overwritten each time a new patch version is posted to\\nthe email thread, and also periodically to check for bitrot caused by changes\\non the master branch.\\n\\nCommitfest entry: https://commitfest.postgresql.org/26/2244\\nPatch(es): https://www.postgresql.org/message-id/900e9708-3db1-1fd8-4877-ccd53ce3b87f@2ndquadrant.com\\nAuthor(s): Peter Eisentraut","di ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11156890708',
#   'type': 'PushEvent',
#   'actor': {'id': 1597567,
#    'login': 'ACT1GMR',
#    'display_login': 'ACT1GMR',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ACT1GMR',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1597567?'},
#   'repo': {'id': 147216804,
#    'name': 'ACT1GMR/podchatwebapp',
#    'url': 'https://api.github.com/repos/ACT1GMR/podchatwebapp'},
#   'payload': {'push_id': 4434300573,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ff665dc4ab1ad6b0f5c321cfe7712f880dec0018',
#    'before': '0708ff1da86f77b56d5c6f9b33266236b74e8a6a',
#    'commits': [{'sha': 'ff665dc4ab1ad6b0f5c321cfe7712f880dec0018',
#      'author': {'email': 'act1gmr@gmail.com', 'name': 'b.salarinia'},
#      'message': 'refactored',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ACT1GMR/podchatwebapp/commits/ff665dc4ab1ad6b0f5c321cfe7712f880dec0018'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890705',
#   'type': 'PushEvent',
#   'actor': {'id': 31173107,
#    'login': 'postgresql-cfbot',
#    'display_login': 'postgresql-cfbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/postgresql-cfbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31173107?'},
#   'repo': {'id': 100835434,
#    'name': 'postgresql-cfbot/postgresql',
#    'url': 'https://api.github.com/repos/postgresql-cfbot/postgresql'},
#   'payload': {'push_id': 4434300571,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/commitfest/26/2244',
#    'head': 'f63b211be6dd7dc13c2983dd42f36e18cc4e7b9f',
#    'before': '8aab73dbafcaaf38ba6cfbd5f4b237b08d6814e4',
#    'commits': [{'sha': 'c4dcd9144ba64946c9f9466748bdb2c51719c8a3',
#      'author': {'email': 'alvherre@alvh.no-ip.org', 'name': 'Alvaro Herrera'},
#      'message': "Avoid splitting C string literals with \\-newline\n\nUsing \\ is unnecessary and ugly, so remove that.  While at it, stitch\nthe literals back into a single line: we've long discouraged splitting\nerror message literals even when they go past the 80 chars line limit,\nto improve greppability.\n\nLeave contrib/tablefunc alone.\n\nDiscussion: https://postgr.es/m/20191223195156.GA12271@alvherre.pgsql",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/postgresql-cfbot/postgresql/commits/c4dcd9144ba64946c9f9466748bdb2c51719c8a3'},
#     {'sha': '8ce3aa9b5914d1ac45ed3f9bc484f66b3c4850c7',
#      'author': {'email': 'michael@paquier.xyz', 'name': 'Michael Paquier'},
#      'message': 'Rename files and headers related to index AM\n\nThe following renaming is done so as source files related to index\naccess methods are more consistent with table access methods (the\noriginal names used for index AMs ware too generic, and could be\nconfused as including features related to table AMs):\n- amapi.h -> indexam.h.\n- amapi.c -> indexamapi.c.  Here we have an equivalent with\nbackend/access/table/tableamapi.c.\n- amvalidate.c -> indexamvalidate.c.\n- amvalidate.h -> indexamvalidate.h.\n- genam.c -> indexgenam.c.\n- genam.h -> indexgenam.h.\n\nThis has been discussed during the development of v12 when table AM was\nworked on, but the renaming never happened.\n\nAuthor: Michael Paquier\nReviewed-by: Fabien Coelho, Julien Rouhaud\nDiscussion: https://postgr.es/m/20191223053434.GF34339@paquier.xyz',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/postgresql-cfbot/postgresql/commits/8ce3aa9b5914d1ac45ed3f9bc484f66b3c4850c7'},
#     {'sha': 'f63b211be6dd7dc13c2983dd42f36e18cc4e7b9f',
#      'author': {'email': 'cfbot@cputube.org', 'name': 'Commitfest Bot'},
#      'message': '[CF 26/2244] Allow cluster owner to bypass authentication\n\nThis commit was automatically generated by a robot at cfbot.cputube.org.\nIt is based on patches submitted to the PostgreSQL mailing lists and\nregistered in the PostgreSQL Commitfest application.\n\nThis branch will be overwritten each time a new patch version is posted to\nthe email thread, and also periodically to check for bitrot caused by changes\non the master branch.\n\nCommitfest entry: https://commitfest.postgresql.org/26/2244\nPatch(es): https://www.postgresql.org/message-id/900e9708-3db1-1fd8-4877-ccd53ce3b87f@2ndquadrant.com\nAuthor(s): Peter Eisentraut',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/postgresql-cfbot/postgresql/commits/f63b211be6dd7dc13c2983dd42f36e18cc4e7b9f'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890703',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 5441976,
#    'login': 'wu-sheng',
#    'display_login': 'wu-sheng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wu-sheng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5441976?'},
#   'repo': {'id': 45721011,
#    'name': 'apache/skywalking',
#    'url': 'https://api.github.com/repos/apache/skywalking'},
#   'payload': {'action': 'opened',
#    'number': 4127,
#    'pull_request': {'url': 'https://api.github.com/repos/apache/skywalking/pulls/4127',
#     'id': 356773784,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU2NzczNzg0',
#     'html_url': 'https://github.com/apache/skywalking/pull/4127',
#     'diff_url': 'https://github.com/apache/skywalking/pull/4127.diff',
#     'patch_url': 'https://github.com/apache/skywalking/pull/4127.patch',
#     'issue_url': 'https://api.github.com/repos/apache/skywalking/issues/4127',
#     'number': 4127,
#     'state': 'open',
#     'locked': False,
#     'title': 'Move lettuce into default plugin',
#     'user': {'login': 'wu-sheng',
#      'id': 5441976,
#      'node_id': 'MDQ6VXNlcjU0NDE5NzY=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/5441976?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wu-sheng',
#      'html_url': 'https://github.com/wu-sheng',
#      'followers_url': 'https://api.github.com/users/wu-sheng/followers',
#      'following_url': 'https://api.github.com/users/wu-sheng/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wu-sheng/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wu-sheng/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wu-sheng/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wu-sheng/orgs',
#      'repos_url': 'https://api.github.com/users/wu-sheng/repos',
#      'events_url': 'https://api.github.com/users/wu-sheng/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wu-sheng/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Follow #4121, moving the lettuce plugin and adjust test cases.',
#     'created_at': '2019-12-25T09:34:59Z',
#     'updated_at': '2019-12-25T09:35:00Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'zhaoyuguang',
#       'id': 10150229,
#       'node_id': 'MDQ6VXNlcjEwMTUwMjI5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/10150229?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zhaoyuguang',
#       'html_url': 'https://github.com/zhaoyuguang',
#       'followers_url': 'https://api.github.com/users/zhaoyuguang/followers',
#       'following_url': 'https://api.github.com/users/zhaoyuguang/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zhaoyuguang/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zhaoyuguang/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zhaoyuguang/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zhaoyuguang/orgs',
#       'repos_url': 'https://api.github.com/users/zhaoyuguang/repos',
#       'events_url': 'https://api.github.com/users/zhaoyuguang/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zhaoyuguang/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'arugal',
#       'id': 26432832,
#       'node_id': 'MDQ6VXNlcjI2NDMyODMy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/26432832?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/arugal',
#       'html_url': 'https://github.com/arugal',
#       'followers_url': 'https://api.github.com/users/arugal/followers',
#       'following_url': 'https://api.github.com/users/arugal/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/arugal/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/arugal/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/arugal/subscriptions',
#       'organizations_url': 'https://api.github.com/users/arugal/orgs',
#       'repos_url': 'https://api.github.com/users/arugal/repos',
#       'events_url': 'https://api.github.com/users/arugal/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/arugal/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'dmsolr',
#       'id': 29735230,
#       'node_id': 'MDQ6VXNlcjI5NzM1MjMw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/29735230?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dmsolr',
#       'html_url': 'https://github.com/dmsolr',
#       'followers_url': 'https://api.github.com/users/dmsolr/followers',
#       'following_url': 'https://api.github.com/users/dmsolr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dmsolr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dmsolr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dmsolr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dmsolr/orgs',
#       'repos_url': 'https://api.github.com/users/dmsolr/repos',
#       'events_url': 'https://api.github.com/users/dmsolr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dmsolr/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 830850387,
#       'node_id': 'MDU6TGFiZWw4MzA4NTAzODc=',
#       'url': 'https://api.github.com/repos/apache/skywalking/labels/agent',
#       'name': 'agent',
#       'color': 'c2e0c6',
#       'default': False,
#       'description': 'Java agent related.'},
#      {'id': 915433204,
#       'node_id': 'MDU6TGFiZWw5MTU0MzMyMDQ=',
#       'url': 'https://api.github.com/repos/apache/skywalking/labels/plugin',
#       'name': 'plugin',
#       'color': '5a910d',
#       'default': False,
#       'description': 'Plugin for agent or collector. Be used to extend the capabilities of default implementor.'},
#      {'id': 904337306,
#       'node_id': 'MDU6TGFiZWw5MDQzMzczMDY=',
#       'url': 'https://api.github.com/repos/apache/skywalking/labels/test',
#       'name': 'test',
#       'color': 'f7f1a5',
#       'default': False,
#       'description': 'Test requirements about performance, feature or before release.'}],
#     'milestone': {'url': 'https://api.github.com/repos/apache/skywalking/milestones/42',
#      'html_url': 'https://github.com/apache/skywalking/milestone/42',
#      'labels_url': 'https://api.github.com/repos/apache/skywalking/milestones/42/labels',
#      'id': 4926794,
#      'node_id': 'MDk6TWlsZXN0b25lNDkyNjc5NA==',
#      'number': 42,
#      'title': '7.0.0',
#      'description': '',
#      'creator': {'login': 'wu-sheng',
#       'id': 5441976,
#       'node_id': 'MDQ6VXNlcjU0NDE5NzY=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/5441976?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wu-sheng',
#       'html_url': 'https://github.com/wu-sheng',
#       'followers_url': 'https://api.github.com/users/wu-sheng/followers',
#       'following_url': 'https://api.github.com/users/wu-sheng/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wu-sheng/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wu-sheng/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wu-sheng/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wu-sheng/orgs',
#       'repos_url': 'https://api.github.com/users/wu-sheng/repos',
#       'events_url': 'https://api.github.com/users/wu-sheng/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wu-sheng/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 15,
#      'closed_issues': 14,
#      'state': 'open',
#      'created_at': '2019-12-13T01:21:21Z',
#      'updated_at': '2019-12-25T09:35:00Z',
#      'due_on': None,
#      'closed_at': None},
#     'commits_url': 'https://api.github.com/repos/apache/skywalking/pulls/4127/commits',
#     'review_comments_url': 'https://api.github.com/repos/apache/skywalking/pulls/4127/comments',
#     'review_comment_url': 'https://api.github.com/repos/apache/skywalking/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/apache/skywalking/issues/4127/comments',
#     'statuses_url': 'https://api.github.com/repos/apache/skywalking/statuses/df923a7806132676021cc19451f7a033fde34999',
#     'head': {'label': 'apache:option2default',
#      'ref': 'option2default',
#      'sha': 'df923a7806132676021cc19451f7a033fde34999',
#      'user': {'login': 'apache',
#       'id': 47359,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apache',
#       'html_url': 'https://github.com/apache',
#       'followers_url': 'https://api.github.com/users/apache/followers',
#       'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apache/orgs',
#       'repos_url': 'https://api.github.com/users/apache/repos',
#       'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apache/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 45721011,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NTcyMTAxMQ==',
#       'name': 'skywalking',
#       'full_name': 'apache/skywalking',
#       'private': False,
#       'owner': {'login': 'apache',
#        'id': 47359,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/apache',
#        'html_url': 'https://github.com/apache',
#        'followers_url': 'https://api.github.com/users/apache/followers',
#        'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#        'organizations_url': 'https://api.github.com/users/apache/orgs',
#        'repos_url': 'https://api.github.com/users/apache/repos',
#        'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/apache/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/apache/skywalking',
#       'description': 'APM, Application Performance Monitoring System',
#       'fork': False,
#       'url': 'https://api.github.com/repos/apache/skywalking',
#       'forks_url': 'https://api.github.com/repos/apache/skywalking/forks',
#       'keys_url': 'https://api.github.com/repos/apache/skywalking/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/apache/skywalking/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/apache/skywalking/teams',
#       'hooks_url': 'https://api.github.com/repos/apache/skywalking/hooks',
#       'issue_events_url': 'https://api.github.com/repos/apache/skywalking/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/apache/skywalking/events',
#       'assignees_url': 'https://api.github.com/repos/apache/skywalking/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/apache/skywalking/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/apache/skywalking/tags',
#       'blobs_url': 'https://api.github.com/repos/apache/skywalking/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/apache/skywalking/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/apache/skywalking/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/apache/skywalking/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/apache/skywalking/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/apache/skywalking/languages',
#       'stargazers_url': 'https://api.github.com/repos/apache/skywalking/stargazers',
#       'contributors_url': 'https://api.github.com/repos/apache/skywalking/contributors',
#       'subscribers_url': 'https://api.github.com/repos/apache/skywalking/subscribers',
#       'subscription_url': 'https://api.github.com/repos/apache/skywalking/subscription',
#       'commits_url': 'https://api.github.com/repos/apache/skywalking/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/apache/skywalking/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/apache/skywalking/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/apache/skywalking/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/apache/skywalking/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/apache/skywalking/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/apache/skywalking/merges',
#       'archive_url': 'https://api.github.com/repos/apache/skywalking/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/apache/skywalking/downloads',
#       'issues_url': 'https://api.github.com/repos/apache/skywalking/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/apache/skywalking/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/apache/skywalking/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/apache/skywalking/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/apache/skywalking/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/apache/skywalking/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/apache/skywalking/deployments',
#       'created_at': '2015-11-07T03:30:36Z',
#       'updated_at': '2019-12-25T09:25:18Z',
#       'pushed_at': '2019-12-25T09:33:35Z',
#       'git_url': 'git://github.com/apache/skywalking.git',
#       'ssh_url': 'git@github.com:apache/skywalking.git',
#       'clone_url': 'https://github.com/apache/skywalking.git',
#       'svn_url': 'https://github.com/apache/skywalking',
#       'homepage': 'https://skywalking.apache.org/',
#       'size': 147319,
#       'stargazers_count': 11823,
#       'watchers_count': 11823,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3435,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 85,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 3435,
#       'open_issues': 85,
#       'watchers': 11823,
#       'default_branch': 'master'}},
#     'base': {'label': 'apache:master',
#      'ref': 'master',
#      'sha': '1e9f929f978ac7fbad11832176ce7b0190181a92',
#      'user': {'login': 'apache',
#       'id': 47359,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apache',
#       'html_url': 'https://github.com/apache',
#       'followers_url': 'https://api.github.com/users/apache/followers',
#       'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apache/orgs',
#       'repos_url': 'https://api.github.com/users/apache/repos',
#       'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apache/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 45721011,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NTcyMTAxMQ==',
#       'name': 'skywalking',
#       'full_name': 'apache/skywalking',
#       'private': False,
#       'owner': {'login': 'apache',
#        'id': 47359,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/apache',
#        'html_url': 'https://github.com/apache',
#        'followers_url': 'https://api.github.com/users/apache/followers',
#        'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#        'organizations_url': 'https://api.github.com/users/apache/orgs',
#        'repos_url': 'https://api.github.com/users/apache/repos',
#        'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/apache/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/apache/skywalking',
#       'description': 'APM, Application Performance Monitoring System',
#       'fork': False,
#       'url': 'https://api.github.com/repos/apache/skywalking',
#       'forks_url': 'https://api.github.com/repos/apache/skywalking/forks',
#       'keys_url': 'https://api.github.com/repos/apache/skywalking/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/apache/skywalking/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/apache/skywalking/teams',
#       'hooks_url': 'https://api.github.com/repos/apache/skywalking/hooks',
#       'issue_events_url': 'https://api.github.com/repos/apache/skywalking/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/apache/skywalking/events',
#       'assignees_url': 'https://api.github.com/repos/apache/skywalking/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/apache/skywalking/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/apache/skywalking/tags',
#       'blobs_url': 'https://api.github.com/repos/apache/skywalking/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/apache/skywalking/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/apache/skywalking/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/apache/skywalking/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/apache/skywalking/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/apache/skywalking/languages',
#       'stargazers_url': 'https://api.github.com/repos/apache/skywalking/stargazers',
#       'contributors_url': 'https://api.github.com/repos/apache/skywalking/contributors',
#       'subscribers_url': 'https://api.github.com/repos/apache/skywalking/subscribers',
#       'subscription_url': 'https://api.github.com/repos/apache/skywalking/subscription',
#       'commits_url': 'https://api.github.com/repos/apache/skywalking/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/apache/skywalking/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/apache/skywalking/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/apache/skywalking/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/apache/skywalking/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/apache/skywalking/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/apache/skywalking/merges',
#       'archive_url': 'https://api.github.com/repos/apache/skywalking/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/apache/skywalking/downloads',
#       'issues_url': 'https://api.github.com/repos/apache/skywalking/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/apache/skywalking/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/apache/skywalking/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/apache/skywalking/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/apache/skywalking/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/apache/skywalking/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/apache/skywalking/deployments',
#       'created_at': '2015-11-07T03:30:36Z',
#       'updated_at': '2019-12-25T09:25:18Z',
#       'pushed_at': '2019-12-25T09:33:35Z',
#       'git_url': 'git://github.com/apache/skywalking.git',
#       'ssh_url': 'git@github.com:apache/skywalking.git',
#       'clone_url': 'https://github.com/apache/skywalking.git',
#       'svn_url': 'https://github.com/apache/skywalking',
#       'homepage': 'https://skywalking.apache.org/',
#       'size': 147319,
#       'stargazers_count': 11823,
#       'watchers_count': 11823,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3435,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 85,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 3435,
#       'open_issues': 85,
#       'watchers': 11823,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/apache/skywalking/pulls/4127'},
#      'html': {'href': 'https://github.com/apache/skywalking/pull/4127'},
#      'issue': {'href': 'https://api.github.com/repos/apache/skywalking/issues/4127'},
#      'comments': {'href': 'https://api.github.com/repos/apache/skywalking/issues/4127/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/apache/skywalking/pulls/4127/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/apache/skywalking/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/apache/skywalking/pulls/4127/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/apache/skywalking/statuses/df923a7806132676021cc19451f7a033fde34999'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 16,
#     'changed_files': 25}},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '11156890694',
#   'type': 'PushEvent',
#   'actor': {'id': 55842131,
#    'login': 'yelena-helen',
#    'display_login': 'yelena-helen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yelena-helen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55842131?'},
#   'repo': {'id': 227348124,
#    'name': 'yelena-helen/techcollab_19_final',
#    'url': 'https://api.github.com/repos/yelena-helen/techcollab_19_final'},
#   'payload': {'push_id': 4434300568,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6ac7aba28e82cfc85f0b2f0dd760b34240810bf2',
#    'before': '2bf41258c0399107552966831f34865f874adc76',
#    'commits': [{'sha': '6ac7aba28e82cfc85f0b2f0dd760b34240810bf2',
#      'author': {'email': '55842131+yelena-helen@users.noreply.github.com',
#       'name': 'yelena-helen'},
#      'message': '新增云南大学',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yelena-helen/techcollab_19_final/commits/6ac7aba28e82cfc85f0b2f0dd760b34240810bf2'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890689',
#   'type': 'CreateEvent',
#   'actor': {'id': 44763919,
#    'login': 'jair2018',
#    'display_login': 'jair2018',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jair2018',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44763919?'},
#   'repo': {'id': 230052204,
#    'name': 'jair2018/jetpack',
#    'url': 'https://api.github.com/repos/jair2018/jetpack'},
#   'payload': {'ref': 'kraftbj-patch-1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890687',
#   'type': 'PushEvent',
#   'actor': {'id': 24805963,
#    'login': 'raul-gherman',
#    'display_login': 'raul-gherman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raul-gherman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24805963?'},
#   'repo': {'id': 230062641,
#    'name': 'raul-gherman/rancher-deployment',
#    'url': 'https://api.github.com/repos/raul-gherman/rancher-deployment'},
#   'payload': {'push_id': 4434300563,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a2880d377ae1753515b3597cc630114e04d5d66b',
#    'before': '1f11cc9c3fda9d073aeee332f1f9f72f1b91829e',
#    'commits': [{'sha': 'a2880d377ae1753515b3597cc630114e04d5d66b',
#      'author': {'email': 'raul.gherman@yandex.com', 'name': 'Raul'},
#      'message': 'Add cloud config file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raul-gherman/rancher-deployment/commits/a2880d377ae1753515b3597cc630114e04d5d66b'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890685',
#   'type': 'CreateEvent',
#   'actor': {'id': 46108131,
#    'login': 'HaykTarkhanyan',
#    'display_login': 'HaykTarkhanyan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HaykTarkhanyan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46108131?'},
#   'repo': {'id': 230079052,
#    'name': 'HaykTarkhanyan/recomendation_letters',
#    'url': 'https://api.github.com/repos/HaykTarkhanyan/recomendation_letters'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890682',
#   'type': 'CreateEvent',
#   'actor': {'id': 59222951,
#    'login': 'arifsaiyad1802',
#    'display_login': 'arifsaiyad1802',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arifsaiyad1802',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59222951?'},
#   'repo': {'id': 230079050,
#    'name': 'arifsaiyad1802/test',
#    'url': 'https://api.github.com/repos/arifsaiyad1802/test'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'test',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890686',
#   'type': 'CreateEvent',
#   'actor': {'id': 19340953,
#    'login': 'jessdesigntan',
#    'display_login': 'jessdesigntan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jessdesigntan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19340953?'},
#   'repo': {'id': 230079053,
#    'name': 'jessdesigntan/workitout',
#    'url': 'https://api.github.com/repos/jessdesigntan/workitout'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890683',
#   'type': 'PushEvent',
#   'actor': {'id': 3617152,
#    'login': 'Norod',
#    'display_login': 'Norod',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Norod',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3617152?'},
#   'repo': {'id': 221222887,
#    'name': 'Norod/my-colab-experiments',
#    'url': 'https://api.github.com/repos/Norod/my-colab-experiments'},
#   'payload': {'push_id': 4434300562,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '093ad7b1073448ea463257c53af0dc34495e8727',
#    'before': 'aa641ff53fb4b7af158560be513e5e5b03f39078',
#    'commits': [{'sha': '093ad7b1073448ea463257c53af0dc34495e8727',
#      'author': {'email': 'Norod@users.noreply.github.com',
#       'name': 'Doron Adler'},
#      'message': 'Updated URL',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Norod/my-colab-experiments/commits/093ad7b1073448ea463257c53af0dc34495e8727'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890680',
#   'type': 'CreateEvent',
#   'actor': {'id': 36789654,
#    'login': 'rufe69',
#    'display_login': 'rufe69',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rufe69',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36789654?'},
#   'repo': {'id': 230079051,
#    'name': 'rufe69/ConwaysGameOfLife',
#    'url': 'https://api.github.com/repos/rufe69/ConwaysGameOfLife'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890679',
#   'type': 'PushEvent',
#   'actor': {'id': 10627694,
#    'login': 'h3d-tuannq',
#    'display_login': 'h3d-tuannq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/h3d-tuannq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10627694?'},
#   'repo': {'id': 214584470,
#    'name': 'h3d-tuannq/ecommerce-house3d',
#    'url': 'https://api.github.com/repos/h3d-tuannq/ecommerce-house3d'},
#   'payload': {'push_id': 4434300560,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/TuanNQ.H3D-Refactor-V2-bak',
#    'head': '1b1fe2a8eac69e8450184eab1cf5be17ecaa7fbd',
#    'before': 'dc6c1a59b0f85af4b4d70be18044d0129479eeaf',
#    'commits': [{'sha': '1b1fe2a8eac69e8450184eab1cf5be17ecaa7fbd',
#      'author': {'email': 'tuannq@projectkit.net', 'name': 'h3d-tuannq'},
#      'message': 'commit for H3D-5336 : pin filter component in store page on mobile.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/h3d-tuannq/ecommerce-house3d/commits/1b1fe2a8eac69e8450184eab1cf5be17ecaa7fbd'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z'},
#  {'id': '11156890676',
#   'type': 'WatchEvent',
#   'actor': {'id': 43278973,
#    'login': 'audiocassette',
#    'display_login': 'audiocassette',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/audiocassette',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43278973?'},
#   'repo': {'id': 221822577,
#    'name': 'Tencent/Hippy',
#    'url': 'https://api.github.com/repos/Tencent/Hippy'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-25T09:35:00Z',
#   'org': {'id': 18461506,
#    'login': 'Tencent',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Tencent',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18461506?'}},
#  {'id': '11156890663',
#   'type': 'PushEvent',
#   'actor': {'id': 34629516,
#    'login': 'RobertWade',
#    'display_login': 'RobertWade',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RobertWade',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34629516?'},
#   'repo': {'id': 230075514,
#    'name': 'RobertWade/Dart-Exercises',
#    'url': 'https://api.github.com/repos/RobertWade/Dart-Exercises'},
#   'payload': {'push_id': 4434300556,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cfae0ddc5b13523c259f1dd18a625aa3913213c7',
#    'before': '7f51aa647ebe93aeb50c4379eaaca3cab597cd96',
#    'commits': [{'sha': 'cfae0ddc5b13523c259f1dd18a625aa3913213c7',
#      'author': {'email': 'rrobewawebdesign@gmail.com', 'name': 'coding_rob'},
#      'message': 'removed comment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RobertWade/Dart-Exercises/commits/cfae0ddc5b13523c259f1dd18a625aa3913213c7'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z'},
#  {'id': '11156890644',
#   'type': 'MemberEvent',
#   'actor': {'id': 857026,
#    'login': 'nadeemmar',
#    'display_login': 'nadeemmar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nadeemmar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/857026?'},
#   'repo': {'id': 176301962,
#    'name': 'nadeemmar/material-ui-phone-number',
#    'url': 'https://api.github.com/repos/nadeemmar/material-ui-phone-number'},
#   'payload': {'member': {'login': 'gmsamara',
#     'id': 11146509,
#     'node_id': 'MDQ6VXNlcjExMTQ2NTA5',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/11146509?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/gmsamara',
#     'html_url': 'https://github.com/gmsamara',
#     'followers_url': 'https://api.github.com/users/gmsamara/followers',
#     'following_url': 'https://api.github.com/users/gmsamara/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/gmsamara/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/gmsamara/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/gmsamara/subscriptions',
#     'organizations_url': 'https://api.github.com/users/gmsamara/orgs',
#     'repos_url': 'https://api.github.com/users/gmsamara/repos',
#     'events_url': 'https://api.github.com/users/gmsamara/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/gmsamara/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z'},
#  {'id': '11156890641',
#   'type': 'PushEvent',
#   'actor': {'id': 26024321,
#    'login': 'ymust',
#    'display_login': 'ymust',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ymust',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26024321?'},
#   'repo': {'id': 229902251,
#    'name': 'ymust/stock.home.cx.github.io',
#    'url': 'https://api.github.com/repos/ymust/stock.home.cx.github.io'},
#   'payload': {'push_id': 4434300540,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '532612c20deddae313488a3f5430b5413edfcae5',
#    'before': '1e2bc57f8de6ea6b95d189b125c62a78bfc023eb',
#    'commits': [{'sha': '532612c20deddae313488a3f5430b5413edfcae5',
#      'author': {'email': 'mail@ymq.one', 'name': 'ymust'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ymust/stock.home.cx.github.io/commits/532612c20deddae313488a3f5430b5413edfcae5'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z'},
#  {'id': '11156890642',
#   'type': 'PushEvent',
#   'actor': {'id': 22169029,
#    'login': 'speedtracker-bot',
#    'display_login': 'speedtracker-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/speedtracker-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22169029?'},
#   'repo': {'id': 99581430,
#    'name': 'lojaskd/speedtracker',
#    'url': 'https://api.github.com/repos/lojaskd/speedtracker'},
#   'payload': {'push_id': 4434300542,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cfd3dbde3304674858361b5a4e1578ef3c0f7969',
#    'before': 'ae9a76948f76ff6ed555069bf184400c719596b6',
#    'commits': [{'sha': 'cfd3dbde3304674858361b5a4e1578ef3c0f7969',
#      'author': {'email': 'mail+speedtrackerbot@eduardoboucas.com',
#       'name': 'SpeedTracker'},
#      'message': 'Add SpeedTracker test (scheduled)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lojaskd/speedtracker/commits/cfd3dbde3304674858361b5a4e1578ef3c0f7969'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z',
#   'org': {'id': 1795083,
#    'login': 'lojaskd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lojaskd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1795083?'}},
#  {'id': '11156890628',
#   'type': 'PushEvent',
#   'actor': {'id': 1626222,
#    'login': 'JustTB',
#    'display_login': 'JustTB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JustTB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1626222?'},
#   'repo': {'id': 162708302,
#    'name': 'Ecohackerfarm/ehfwebsite',
#    'url': 'https://api.github.com/repos/Ecohackerfarm/ehfwebsite'},
#   'payload': {'push_id': 4434300533,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b8729ec030d95be94093a43e3ef675359c8bd800',
#    'before': 'a19eaef6ebf4c4955c5f5be749214965e3a96cf8',
#    'commits': [{'sha': 'b8729ec030d95be94093a43e3ef675359c8bd800',
#      'author': {'email': 'franz@ecohackerfarm.org', 'name': 'JustTB'},
#      'message': 'some improvements styles and SEO',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ecohackerfarm/ehfwebsite/commits/b8729ec030d95be94093a43e3ef675359c8bd800'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z',
#   'org': {'id': 29238614,
#    'login': 'Ecohackerfarm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Ecohackerfarm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29238614?'}},
#  {'id': '11156890617',
#   'type': 'PushEvent',
#   'actor': {'id': 34019996,
#    'login': 'chengyi4225372',
#    'display_login': 'chengyi4225372',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chengyi4225372',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34019996?'},
#   'repo': {'id': 224784580,
#    'name': 'chengyi4225372/hys',
#    'url': 'https://api.github.com/repos/chengyi4225372/hys'},
#   'payload': {'push_id': 4434300530,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '49c474afab7aa4b8d612aaa444354f1238cfdb10',
#    'before': '7ced5b34f992bb4060f99f5456a471f2c03dd00a',
#    'commits': [{'sha': '49c474afab7aa4b8d612aaa444354f1238cfdb10',
#      'author': {'email': '125495458@qq.com', 'name': 'yashun'},
#      'message': 'add',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chengyi4225372/hys/commits/49c474afab7aa4b8d612aaa444354f1238cfdb10'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z'},
#  {'id': '11156890622',
#   'type': 'WatchEvent',
#   'actor': {'id': 11289334,
#    'login': 'ching56',
#    'display_login': 'ching56',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ching56',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11289334?'},
#   'repo': {'id': 110072462,
#    'name': 'geosigno/simpleParallax',
#    'url': 'https://api.github.com/repos/geosigno/simpleParallax'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-25T09:34:59Z'},
#  {'id': '11156890618',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 2579311,
#    'login': 'nemezxxx',
#    'display_login': 'nemezxxx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nemezxxx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2579311?'},
#   'repo': {'id': 122426901,
#    'name': 'ApolloFoundation/Apollo',
#    'url': 'https://api.github.com/repos/ApolloFoundation/Apollo'},
#   'payload': {'action': 'opened',
#    'number': 839,
#    'pull_request': {'url': 'https://api.github.com/repos/ApolloFoundation/Apollo/pulls/839',
#     'id': 356773781,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU2NzczNzgx',
#     'html_url': 'https://github.com/ApolloFoundation/Apollo/pull/839',
#     'diff_url': 'https://github.com/ApolloFoundation/Apollo/pull/839.diff',
#     'patch_url': 'https://github.com/ApolloFoundation/Apollo/pull/839.patch',
#     'issue_url': 'https://api.github.com/repos/ApolloFoundation/Apollo/issues/839',
#     'number': 839,
#     'state': 'open',
#     'locked': False,
#     'title': 'Fix/apl tv updates',
#     'user': {'login': 'nemezxxx',
#      'id': 2579311,
#      'node_id': 'MDQ6VXNlcjI1NzkzMTE=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/2579311?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nemezxxx',
#      'html_url': 'https://github.com/nemezxxx',
#      'followers_url': 'https://api.github.com/users/nemezxxx/followers',
#      'following_url': 'https://api.github.com/users/nemezxxx/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nemezxxx/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nemezxxx/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nemezxxx/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nemezxxx/orgs',
#      'repos_url': 'https://api.github.com/users/nemezxxx/repos',
#      'events_url': 'https://api.github.com/users/nemezxxx/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nemezxxx/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '1) including zero intervals\r\n2) dependency of open upon prev close',
#     'created_at': '2019-12-25T09:34:58Z',
#     'updated_at': '2019-12-25T09:34:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'AndrewBoyarsky',
#       'id': 22385561,
#       'node_id': 'MDQ6VXNlcjIyMzg1NTYx',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/22385561?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AndrewBoyarsky',
#       'html_url': 'https://github.com/AndrewBoyarsky',
#       'followers_url': 'https://api.github.com/users/AndrewBoyarsky/followers',
#       'following_url': 'https://api.github.com/users/AndrewBoyarsky/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AndrewBoyarsky/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AndrewBoyarsky/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AndrewBoyarsky/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AndrewBoyarsky/orgs',
#       'repos_url': 'https://api.github.com/users/AndrewBoyarsky/repos',
#       'events_url': 'https://api.github.com/users/AndrewBoyarsky/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AndrewBoyarsky/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'andrii-firstbridge',
#       'id': 57639158,
#       'node_id': 'MDQ6VXNlcjU3NjM5MTU4',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/57639158?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/andrii-firstbridge',
#       'html_url': 'https://github.com/andrii-firstbridge',
#       'followers_url': 'https://api.github.com/users/andrii-firstbridge/followers',
#       'following_url': 'https://api.github.com/users/andrii-firstbridge/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/andrii-firstbridge/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/andrii-firstbridge/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/andrii-firstbridge/subscriptions',
# ...
#     'blobs_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/languages',
#     'stargazers_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/stargazers',
#     'contributors_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/contributors',
#     'subscribers_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/subscribers',
#     'subscription_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/subscription',
#     'commits_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/merges',
#     'archive_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/downloads',
#     'issues_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/MahmoudAbdallahMostafa/plugins/deployments',
#     'created_at': '2019-12-25T09:34:58Z',
#     'updated_at': '2019-12-25T09:14:29Z',
#     'pushed_at': '2019-12-23T23:12:39Z',
#     'git_url': 'git://github.com/MahmoudAbdallahMostafa/plugins.git',
#     'ssh_url': 'git@github.com:MahmoudAbdallahMostafa/plugins.git',
#     'clone_url': 'https://github.com/MahmoudAbdallahMostafa/plugins.git',
#     'svn_url': 'https://github.com/MahmoudAbdallahMostafa/plugins',
#     'homepage': 'https://flutter.dev/',
#     'size': 15162,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'bsd-3-clause',
#      'name': 'BSD 3-Clause "New" or "Revised" License',
#      'spdx_id': 'BSD-3-Clause',
#      'url': 'https://api.github.com/licenses/bsd-3-clause',
#      'node_id': 'MDc6TGljZW5zZTU='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z',
#   'org': {'id': 14101776,
#    'login': 'flutter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/flutter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14101776?'}},
#  {'id': '11156890604',
#   'type': 'PushEvent',
#   'actor': {'id': 1073784,
#    'login': 'niden',
#    'display_login': 'niden',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/niden',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1073784?'},
#   'repo': {'id': 4977367,
#    'name': 'phalcon/docs',
#    'url': 'https://api.github.com/repos/phalcon/docs'},
#   'payload': {'push_id': 4434300520,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_4.0',
#    'head': 'eacbad2bc6e6c32e824b110c0c0c34378e1280b9',
#    'before': '78f00139463b521a2f0883da3da2d9658cef766c',
#    'commits': [{'sha': 'eacbad2bc6e6c32e824b110c0c0c34378e1280b9',
#      'author': {'email': 'nikos@niden.net', 'name': 'Nikolaos Dimopoulos'},
#      'message': 'New translations devtools.md (Turkish)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/phalcon/docs/commits/eacbad2bc6e6c32e824b110c0c0c34378e1280b9'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z',
#   'org': {'id': 1221505,
#    'login': 'phalcon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/phalcon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1221505?'}},
#  {'id': '11156890603',
#   'type': 'ForkEvent',
#   'actor': {'id': 56444859,
#    'login': 'MohamedBelkheirRBK',
#    'display_login': 'MohamedBelkheirRBK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MohamedBelkheirRBK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56444859?'},
#   'repo': {'id': 230073402,
#    'name': 'RBK-RebootKamp-Tunisia/rbktn01-shortly-deploy',
#    'url': 'https://api.github.com/repos/RBK-RebootKamp-Tunisia/rbktn01-shortly-deploy'},
#   'payload': {'forkee': {'id': 230079047,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzAwNzkwNDc=',
#     'name': 'rbktn01-shortly-deploy',
#     'full_name': 'MohamedBelkheirRBK/rbktn01-shortly-deploy',
#     'private': False,
#     'owner': {'login': 'MohamedBelkheirRBK',
#      'id': 56444859,
#      'node_id': 'MDQ6VXNlcjU2NDQ0ODU5',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/56444859?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MohamedBelkheirRBK',
#      'html_url': 'https://github.com/MohamedBelkheirRBK',
#      'followers_url': 'https://api.github.com/users/MohamedBelkheirRBK/followers',
#      'following_url': 'https://api.github.com/users/MohamedBelkheirRBK/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MohamedBelkheirRBK/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MohamedBelkheirRBK/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MohamedBelkheirRBK/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MohamedBelkheirRBK/orgs',
#      'repos_url': 'https://api.github.com/users/MohamedBelkheirRBK/repos',
#      'events_url': 'https://api.github.com/users/MohamedBelkheirRBK/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MohamedBelkheirRBK/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/MohamedBelkheirRBK/rbktn01-shortly-deploy',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy',
#     'forks_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/forks',
#     'keys_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/teams',
#     'hooks_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/hooks',
#     'issue_events_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/events',
#     'assignees_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/tags',
#     'blobs_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/languages',
#     'stargazers_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/stargazers',
#     'contributors_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/contributors',
#     'subscribers_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/subscribers',
#     'subscription_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/subscription',
#     'commits_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/merges',
#     'archive_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/downloads',
#     'issues_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/MohamedBelkheirRBK/rbktn01-shortly-deploy/deployments',
#     'created_at': '2019-12-25T09:34:57Z',
#     'updated_at': '2019-12-25T08:54:33Z',
#     'pushed_at': '2019-12-25T08:57:16Z',
#     'git_url': 'git://github.com/MohamedBelkheirRBK/rbktn01-shortly-deploy.git',
#     'ssh_url': 'git@github.com:MohamedBelkheirRBK/rbktn01-shortly-deploy.git',
#     'clone_url': 'https://github.com/MohamedBelkheirRBK/rbktn01-shortly-deploy.git',
#     'svn_url': 'https://github.com/MohamedBelkheirRBK/rbktn01-shortly-deploy',
#     'homepage': None,
#     'size': 0,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z',
#   'org': {'id': 56084605,
#    'login': 'RBK-RebootKamp-Tunisia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/RBK-RebootKamp-Tunisia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56084605?'}},
#  {'id': '11156890599',
#   'type': 'PushEvent',
#   'actor': {'id': 8425314,
#    'login': 'tommyvercetti',
#    'display_login': 'tommyvercetti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tommyvercetti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8425314?'},
#   'repo': {'id': 230074989,
#    'name': 'tommyvercetti/WebAcademy_SwiftCourses',
#    'url': 'https://api.github.com/repos/tommyvercetti/WebAcademy_SwiftCourses'},
#   'payload': {'push_id': 4434300521,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9b58f21d47c21d683de660e504fc719f0d9d329f',
#    'before': 'da10345319d6e63e4becc784b14a249f02f407a4',
#    'commits': [{'sha': '9b58f21d47c21d683de660e504fc719f0d9d329f',
#      'author': {'email': 'andriancrick@gmail.com', 'name': 'tommyvercetti'},
#      'message': 'assignment 1.3 finished',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tommyvercetti/WebAcademy_SwiftCourses/commits/9b58f21d47c21d683de660e504fc719f0d9d329f'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z'},
#  {'id': '11156890589',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 114471457,
#    'name': 'Lombiq/Arithmetics',
#    'url': 'https://api.github.com/repos/Lombiq/Arithmetics'},
#   'payload': {'push_id': 4434300515,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/HAST-132',
#    'head': 'b4dd23def5490c868100544da65bef62ad4a9df0',
#    'before': 'b4dd23def5490c868100544da65bef62ad4a9df0',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11156890581',
#   'type': 'PushEvent',
#   'actor': {'id': 15831643,
#    'login': 'psilo909',
#    'display_login': 'psilo909',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/psilo909',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15831643?'},
#   'repo': {'id': 53928710,
#    'name': 'smarthomeNG/smarthome',
#    'url': 'https://api.github.com/repos/smarthomeNG/smarthome'},
#   'payload': {'push_id': 4434300510,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/develop',
#    'head': '58922ac58e651536c8274e5f4e6aedf383590f57',
#    'before': '6bc7a82d2cd512177c3190c331a47c368e1bcca9',
#    'commits': [{'sha': '97719b00c6f432e4f929b203fe8aba177c1ad327',
#      'author': {'email': 'rene.friess@gmx.de', 'name': 'psilo909'},
#      'message': 'metadata.py: improved version checks and error/warning messages for plugins',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smarthomeNG/smarthome/commits/97719b00c6f432e4f929b203fe8aba177c1ad327'},
#     {'sha': '58922ac58e651536c8274e5f4e6aedf383590f57',
#      'author': {'email': 'rene.friess@gmx.de', 'name': 'psilo909'},
#      'message': "Merge branch 'develop' of https://github.com/smarthomeNG/smarthome into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smarthomeNG/smarthome/commits/58922ac58e651536c8274e5f4e6aedf383590f57'}]},
#   'public': True,
#   'created_at': '2019-12-25T09:34:58Z',
#   'org': {'id': 17847102,
#    'login': 'smarthomeNG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/smarthomeNG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17847102?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests, json

r = requests.get("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
#    'text': 'Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.',
# ...
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1290f1c57001592f12a',
#    'type': 'cat',
#    'text': 'Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df895e6b803950015c7b378',
#    'type': 'cat',
#    'text': 'แมวมี 9 ชีวิตนะ :D.',
#    'user': {'_id': '5df86094c555480015a3e3ae',
#     'name': {'first': 'Thanadols', 'last': 'Supho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df895ffb803950015c7b379',
#    'type': 'cat',
#    'text': 'Aaa.',
#    'user': {'_id': '5df86094c555480015a3e3ae',
#     'name': {'first': 'Thanadols', 'last': 'Supho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df8a7cbb803950015c7b37e',
#    'type': 'cat',
#    'text': 'Cats survive is you throw them out of any window.',
#    'user': {'_id': '5df89892b803950015c7b37a',
#     'name': {'first': 'Wolfgang', 'last': 'Gruel'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel")
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.15},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 226.25},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.28},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 25.73},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.48},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 224.21},
#   {'StationIdentifier': '1730H075',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 92.83},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 164.37},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.2},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 138.73},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 740.49},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 26.75},
#   {'StationIdentifier': '1670H004',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 2.98},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.7},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 266.23},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 38.99},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.14},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.1},
#   {'StationIdentifier': '1730H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 43.48},
#   {'StationIdentifier': '1730H068',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.14},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.01},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.05},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 124.1},
#   {'StationIdentifier': '1630H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 65.83},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.04},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.32},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.4},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.19},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 1.57},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 0.13},
#   {'StationIdentifier': '1650H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 5.62},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '2200H026',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 106.73},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -0.15},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.76},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.01},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 26.14},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.45},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.54},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.03},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 175.97},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 278.47},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 11.27},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 69.07},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 13.13},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 27.2},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 39.76},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.89},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.16},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 48.29},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.06},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.59},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.76},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1068.94},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 12.13},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 380.46},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 95.66},
#   {'StationIdentifier': '1350H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 259.67},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 21.23},
#   {'StationIdentifier': '1510H079',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 187.7},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 470.82},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.6},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 72.35},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 317.97},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.39},
#   {'StationIdentifier': '1510H071',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 20.5},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '1420H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 639.41},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 440.47},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 97.9},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 15.74},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 346.5},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 91.76},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 83.01},
#   {'StationIdentifier': '1400H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 622.43},
#   {'StationIdentifier': '1420H055',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 318.68},
#   {'StationIdentifier': '1340H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.08},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 282.05},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.29},
#   {'StationIdentifier': '1340H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.37},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 191.55},
#   {'StationIdentifier': '1140H106',
#    'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'WaterLevel': 49.11},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 58.49},
#   {'StationIdentifier': '1420H049',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 54.19},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 169.81},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -1.01},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 7.38},
#   {'StationIdentifier': '1140H108',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 12.12},
#   {'StationIdentifier': '1140H099',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 263.49},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 22.09},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'WaterLevel': 310.14},
#   {'StationIdentifier': '1290H002',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
